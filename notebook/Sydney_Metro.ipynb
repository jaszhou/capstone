# %% [markdown]
# <h1> Sydney Metro Data Science </h1>

# %% [markdown]
# Import libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          82 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.17.0         | 49 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-2.2.2               |           py36_1         461 KB  conda-forge
#     branca-0.3.0               |             py_0          24 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         558 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py36_1 conda-forge
#     branca:  0.3.0-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-2.2.2         | 461 KB    | ##################################### | 100%
# branca-0.3.0         | 24 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset

# %%
import pandas as pd

 
df = pd.read_csv('postcodes.csv')
df.head()
# Out:
#     id  postcode  suburb state  latitude  longitude
# 0  398      1001  Sydney   NSW    -33.79     151.27
# 1  399      1002  Sydney   NSW    -33.79     151.27
# 2  400      1003  Sydney   NSW    -33.79     151.27
# 3  401      1004  Sydney   NSW    -33.79     151.27
# 4  402      1005  Sydney   NSW    -33.79     151.27

# %% [markdown]
# Define a function to get GPS for a suburb

# %% [markdown]
# #### Data filtering

# %%
df=df[['postcode','suburb','longitude','latitude']]
df=df.drop_duplicates(subset=['suburb'], keep='first')
df = df[df.longitude != 0.00]
df = df[df.postcode >= 2000]
#df.head(10)
df.shape
# Out:
# (4527, 4)

# %% [markdown]
# We'd like to select a suburb called Beecroft as the central point for the data analysis

# %% [markdown]
# Get GEO location for the suburb

# %%
address = 'Beecroft, NSW'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Beecroft are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Beecroft are -33.7497631, 151.0657475.

# %%
df.head(10)
# Out:
#      postcode                    suburb  longitude  latitude
# 318      2000                Barangaroo     151.21    -33.86
# 319      2000               Dawes Point     151.21    -33.86
# 321      2000             Millers Point     151.21    -33.86
# 322      2000          Parliament House     151.21    -33.86
# 325      2000                 The Rocks     151.21    -33.86
# 327      2002              World Square     146.41    -35.97
# 330      2006  The University Of Sydney     151.19    -33.89
# 332      2007                    Ultimo     151.20    -33.88
# 333      2008               Chippendale     151.20    -33.89
# 334      2008                Darlington     151.20    -33.89

# %% [markdown]
# Manually pick the suburbs nearby

# %%
neighborhoods = df[df['postcode'].isin([2117,2119,2118,2120,2121,2122,2125,2126,2076])].reset_index(drop=True)


neighborhoods.shape
# Out:
# (20, 4)

# %% [markdown]
# #### Create a map of Beecroft with neighborhoods superimposed on top.

# %%
map_beecroft = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, suburb in zip(neighborhoods['latitude'], neighborhoods['longitude'], neighborhoods['suburb']):
    label = '{}'.format(suburb)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_beecroft)  
    
map_beecroft
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'VDFTNYUMJI3FIAI2E1GDVXWGMBJZYB30DCLYIJA5IIYQXX3F' # your Foursquare ID
CLIENT_SECRET = 'ZQSBPY4I2RWWPXV1ZHWCHV4YQORZPEOSWGFNDV33GWE2T4CO' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VDFTNYUMJI3FIAI2E1GDVXWGMBJZYB30DCLYIJA5IIYQXX3F
# CLIENT_SECRET:ZQSBPY4I2RWWPXV1ZHWCHV4YQORZPEOSWGFNDV33GWE2T4CO

# %% [markdown]
# #### Let's explore the neighborhood in our dataframe.

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = df.loc[df['suburb'] == 'Beecroft', 'latitude'].iloc[0] # neighborhood latitude value
neighborhood_longitude = df.loc[df['suburb'] == 'Beecroft', 'longitude'].iloc[0] # neighborhood longitude value



neighborhood_name = df.loc[df['suburb'] == 'Beecroft', 'suburb'].iloc[0] # neighborhood name


print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Beecroft are -33.75, 151.06.

# %% [markdown]
# #### Now, let's get the top 100 venues that are in Beecroft within a radius of 500 meters.

# %% [markdown]
# First, let's create the GET request URL. Name your URL **url**.

# %%
# type your answer here
LIMIT = 100
radius = 500


url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=VDFTNYUMJI3FIAI2E1GDVXWGMBJZYB30DCLYIJA5IIYQXX3F&client_secret=ZQSBPY4I2RWWPXV1ZHWCHV4YQORZPEOSWGFNDV33GWE2T4CO&v=20180605&ll=-33.75,151.06&radius=500&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
#results

# %% [markdown]
# let's borrow the get_category_type function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a pandas dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                                 name            categories        lat  \
# 0                         Woolworths           Supermarket -33.749232
# 1                     Yummy Kitchens    Chinese Restaurant -33.750190
# 2                     Beecroft Place         Shopping Mall -33.749210
# 3                          Cafe Bela                  Café -33.749362
# 4                       Beehive Cafe                  Café -33.750334
# 5            Sevardi Cucina Italiana    Italian Restaurant -33.749405
# 6  Beecroft Gourmet Chicken & Salads  Fast Food Restaurant -33.749413
# 7                          Franklins     Convenience Store -33.749312
#
#           lng
# 0  151.065080
# 1  151.064923
# 2  151.064855
# 3  151.065152
# 4  151.065210
# 5  151.065345
# 6  151.065347
# 7  151.065334

# %% [markdown]
# And how many venues were returned by Foursquare?

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 8 venues were returned by Foursquare.

# %% [markdown]
# ## 2. Explore Neighborhoods in Beecroft

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Beecroft

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now write the code to run the above function on each neighborhood and create a new dataframe called *beecroft_venues*.

# %% [markdown]
# The neighbor suburbs are 2117,2119,2118,2120,2121,2122,2125,2126,2076

# %%
neighborhoods = df[df['postcode'].isin([2117,2119,2118,2120,2121,2122,2125,2126,2076])].reset_index(drop=True)

neighborhoods

beecroft_venues = getNearbyVenues(names=neighborhoods['suburb'],
                                   latitudes=neighborhoods['latitude'],
                                   longitudes=neighborhoods['longitude']
                                  )
# Out:
# Normanhurst
# North Wahroonga
# Wahroonga
# Dundas
# Dundas Valley
# Oatlands
# Telopea
# Carlingford
# Carlingford Court
# Carlingford North
# Kingsdene
# Beecroft
# Cheltenham
# Thornleigh
# Westleigh
# North Epping
# Eastwood
# Marsfield
# West Pennant Hills
# Cherrybrook

# %%
beecroft_venues.shape
# Out:
# (764, 7)

# %%
beecroft_venues.groupby('Neighborhood').count()
# Out:
#                     Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Beecroft                               38                      38     38
# Carlingford                            29                      29     29
# Carlingford Court                      29                      29     29
# Carlingford North                      29                      29     29
# Cheltenham                             38                      38     38
# Cherrybrook                            16                      16     16
# Dundas                                 18                      18     18
# Dundas Valley                          18                      18     18
# Eastwood                               74                      74     74
# Kingsdene                              29                      29     29
# Marsfield                              74                      74     74
# Normanhurst                            60                      60     60
# North Epping                           24                      24     24
# North Wahroonga                        60                      60     60
# Oatlands                               18                      18     18
# Telopea                                18                      18     18
# Thornleigh                             59                      59     59
# Wahroonga                              60                      60     60
# West Pennant Hills                     14                      14     14
# Westleigh                              59                      59     59
#
#                     Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Beecroft                        38               38              38
# Carlingford                     29               29              29
# Carlingford Court               29               29              29
# Carlingford North               29               29              29
# Cheltenham                      38               38              38
# Cherrybrook                     16               16              16
# Dundas                          18               18              18
# Dundas Valley                   18               18              18
# Eastwood                        74               74              74
# Kingsdene                       29               29              29
# Marsfield                       74               74              74
# Normanhurst                     60               60              60
# North Epping                    24               24              24
# North Wahroonga                 60               60              60
# Oatlands                        18               18              18
# Telopea                         18               18              18
# Thornleigh                      59               59              59
# Wahroonga                       60               60              60
# West Pennant Hills              14               14              14
# Westleigh                       59               59              59

# %%
print('There are {} uniques categories.'.format(len(beecroft_venues['Venue Category'].unique())))
# Out:
# There are 73 uniques categories.

# %% [markdown]
# ## 3. Analyze Each Neighborhood

# %%
# one hot encoding
beecroft_onehot = pd.get_dummies(beecroft_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
beecroft_onehot['Neighborhood'] = beecroft_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [beecroft_onehot.columns[-1]] + list(beecroft_onehot.columns[:-1])
beecroft_onehot = beecroft_onehot[fixed_columns]

beecroft_onehot.shape
# Out:
# (764, 74)

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
beecroft_grouped = beecroft_onehot.groupby('Neighborhood').mean().reset_index()
beecroft_grouped.shape
# Out:
# (20, 74)

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = beecroft_grouped['Neighborhood']

for ind in np.arange(beecroft_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(beecroft_grouped.iloc[ind, :], num_top_venues)

#neighborhoods_venues_sorted

# %% [markdown]
# ## 4. Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 3 clusters.

# %%
# set number of clusters
kclusters = 3

beecroft_grouped_clustering = beecroft_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(beecroft_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:12]
# Out:
# array([1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 1, 1], dtype=int32)

# %%
beecroft_grouped
# Out:
#           Neighborhood  American Restaurant  Arts & Crafts Store  \
# 0             Beecroft             0.026316             0.026316
# 1          Carlingford             0.000000             0.000000
# 2    Carlingford Court             0.000000             0.000000
# 3    Carlingford North             0.000000             0.000000
# 4           Cheltenham             0.026316             0.026316
# 5          Cherrybrook             0.000000             0.000000
# 6               Dundas             0.000000             0.000000
# 7        Dundas Valley             0.000000             0.000000
# 8             Eastwood             0.000000             0.000000
# 9            Kingsdene             0.000000             0.000000
# 10           Marsfield             0.000000             0.000000
# 11         Normanhurst             0.000000             0.000000
# 12        North Epping             0.000000             0.000000
# 13     North Wahroonga             0.000000             0.000000
# 14            Oatlands             0.000000             0.000000
# 15             Telopea             0.000000             0.000000
# 16          Thornleigh             0.000000             0.000000
# 17           Wahroonga             0.000000             0.000000
# 18  West Pennant Hills             0.000000             0.000000
# 19           Westleigh             0.000000             0.000000
#
#     Asian Restaurant  Athletics & Sports  Australian Restaurant  Auto Garage  \
# 0           0.000000            0.000000               0.000000     0.000000
# 1           0.034483            0.000000               0.000000     0.000000
# 2           0.034483            0.000000               0.000000     0.000000
# 3           0.034483            0.000000               0.000000     0.000000
# 4           0.000000            0.000000               0.000000     0.000000
# 5           0.000000            0.000000               0.000000     0.000000
# 6           0.055556            0.000000               0.000000     0.000000
# 7           0.055556            0.000000               0.000000     0.000000
# 8           0.013514            0.013514               0.000000     0.000000
# 9           0.034483            0.000000               0.000000     0.000000
# 10          0.013514            0.013514               0.000000     0.000000
# 11          0.050000            0.000000               0.016667     0.000000
# 12          0.041667            0.000000               0.000000     0.000000
# 13          0.050000            0.000000               0.016667     0.000000
# 14          0.055556            0.000000               0.000000     0.000000
# 15          0.055556            0.000000               0.000000     0.000000
# 16          0.016949            0.000000               0.000000     0.016949
# 17          0.050000            0.000000               0.016667     0.000000
# 18          0.000000            0.000000               0.000000     0.000000
# 19          0.016949            0.000000               0.000000     0.016949
#
#     BBQ Joint    Bakery  Big Box Store  Bubble Tea Shop  Burger Joint  \
# 0    0.026316  0.052632       0.000000         0.000000      0.000000
# 1    0.000000  0.034483       0.034483         0.000000      0.034483
# 2    0.000000  0.034483       0.034483         0.000000      0.034483
# 3    0.000000  0.034483       0.034483         0.000000      0.034483
# 4    0.026316  0.052632       0.000000         0.000000      0.000000
# 5    0.000000  0.000000       0.000000         0.000000      0.000000
# 6    0.000000  0.000000       0.000000         0.000000      0.000000
# 7    0.000000  0.000000       0.000000         0.000000      0.000000
# 8    0.040541  0.027027       0.000000         0.013514      0.013514
# 9    0.000000  0.034483       0.034483         0.000000      0.034483
# 10   0.040541  0.027027       0.000000         0.013514      0.013514
# 11   0.016667  0.033333       0.016667         0.000000      0.016667
# 12   0.041667  0.000000       0.000000         0.000000      0.000000
# 13   0.016667  0.033333       0.016667         0.000000      0.016667
# 14   0.000000  0.000000       0.000000         0.000000      0.000000
# 7      0.000000  0.000000
# 8      0.000000  0.000000
# 9      0.000000  0.000000
# 10     0.000000  0.000000
# 11     0.000000  0.000000
# 12     0.000000  0.000000
# 13     0.000000  0.000000
# 14     0.000000  0.000000
# 15     0.000000  0.000000
# 16     0.016949  0.000000
# 17     0.000000  0.000000
# 18     0.000000  0.071429
# 19     0.016949  0.000000

# %%
neighborhoods.columns=['PostCode','Neighborhood','Longitude','Latitude']
neighborhoods.shape
# Out:
# (20, 4)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
beecroft_merged = neighborhoods

# add clustering labels
beecroft_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
beecroft_merged = beecroft_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

beecroft_merged
# Out:
#     PostCode        Neighborhood  Longitude  Latitude  Cluster Labels  \
# 0       2076         Normanhurst     151.10    -33.72               1
# 1       2076     North Wahroonga     151.10    -33.72               0
# 2       2076           Wahroonga     151.10    -33.72               0
# 3       2117              Dundas     151.04    -33.80               0
# 4       2117       Dundas Valley     151.04    -33.80               1
# 5       2117            Oatlands     151.04    -33.80               0
# 6       2117             Telopea     151.04    -33.80               0
# 7       2118         Carlingford     151.05    -33.78               0
# 8       2118   Carlingford Court     151.05    -33.78               1
# 9       2118   Carlingford North     151.05    -33.78               0
# 10      2118           Kingsdene     151.05    -33.78               1
# 11      2119            Beecroft     151.06    -33.75               1
# 12      2119          Cheltenham     151.06    -33.75               1
# 13      2120          Thornleigh     151.07    -33.74               1
# 14      2120           Westleigh     151.07    -33.74               0
# 15      2121        North Epping     151.08    -33.77               0
# 16      2122            Eastwood     151.08    -33.79               1
# 17      2122           Marsfield     151.08    -33.79               1
# 18      2125  West Pennant Hills     151.04    -33.75               2
# 19      2126         Cherrybrook     151.04    -33.72               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                   Café                   Gym     Indian Restaurant
# 1                   Café                   Gym     Indian Restaurant
# 2                   Café                   Gym     Indian Restaurant
# 3            Pizza Place         Grocery Store                  Café
# 4            Pizza Place         Grocery Store                  Café
# 5            Pizza Place         Grocery Store                  Café
# 6            Pizza Place         Grocery Store                  Café
# 7   Fast Food Restaurant                  Café         Train Station
# 8   Fast Food Restaurant                  Café         Train Station
# 9   Fast Food Restaurant                  Café         Train Station
# 10  Fast Food Restaurant                  Café         Train Station
# 11                  Café           Pizza Place                Bakery
# 12                  Café           Pizza Place                Bakery
# 13                  Café           Pizza Place       Thai Restaurant
# 14                  Café           Pizza Place       Thai Restaurant
# 15       Thai Restaurant     Indian Restaurant           Pizza Place
# 16    Chinese Restaurant   Japanese Restaurant           Supermarket
# 17    Chinese Restaurant   Japanese Restaurant           Supermarket
# 18           Pizza Place                  Park                   Zoo
# 19         Shopping Mall          Liquor Store    Italian Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0       Asian Restaurant                   Park    Chinese Restaurant
# 1       Asian Restaurant                   Park    Chinese Restaurant
# 2       Asian Restaurant                   Park    Chinese Restaurant
# 3            Supermarket                    Pub  Fast Food Restaurant
# 4            Supermarket                    Pub  Fast Food Restaurant
# 5            Supermarket                    Pub  Fast Food Restaurant
# 6            Supermarket                    Pub  Fast Food Restaurant
# 7            Supermarket     Italian Restaurant         Shopping Mall
# 8            Supermarket     Italian Restaurant         Shopping Mall
# 9            Supermarket     Italian Restaurant         Shopping Mall
# 10           Supermarket     Italian Restaurant         Shopping Mall
# 11       Thai Restaurant            Supermarket                   Zoo
# 12       Thai Restaurant            Supermarket                   Zoo
# 13          Liquor Store     Chinese Restaurant              Platform
# 14          Liquor Store     Chinese Restaurant              Platform
# 15    Italian Restaurant            Social Club   Fried Chicken Joint
# 16             BBQ Joint  Vietnamese Restaurant     Korean Restaurant
# 17             BBQ Joint  Vietnamese Restaurant     Korean Restaurant
# 18                Bakery            Bus Station                   Spa
# 19         Grocery Store                   Park          Noodle House
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                 Bakery         Grocery Store     Electronics Store
# 1                 Bakery         Grocery Store     Electronics Store
# 2                 Bakery         Grocery Store     Electronics Store
# 3         Sandwich Place    Chinese Restaurant          Soccer Field
# 4         Sandwich Place    Chinese Restaurant          Soccer Field
# 5         Sandwich Place    Chinese Restaurant          Soccer Field
# 6         Sandwich Place    Chinese Restaurant          Soccer Field
# 7                    Gym  Gym / Fitness Center            Food Court
# 8                    Gym  Gym / Fitness Center            Food Court
# 9                    Gym  Gym / Fitness Center            Food Court
# 10                   Gym  Gym / Fitness Center            Food Court
# 11  Fast Food Restaurant                  Park          Noodle House
# 12  Fast Food Restaurant                  Park          Noodle House
# 13  Gym / Fitness Center  Fast Food Restaurant         Shopping Mall
# 14  Gym / Fitness Center  Fast Food Restaurant         Shopping Mall
# 15      Football Stadium     Korean Restaurant      Malay Restaurant
# 16                  Café       Thai Restaurant     Indian Restaurant
# 17                  Café       Thai Restaurant     Indian Restaurant
# 18            Sports Bar          Liquor Store           Supermarket
# 19        Sandwich Place                  Café           Supermarket
#
#    10th Most Common Venue
# 0     Japanese Restaurant
# 1     Japanese Restaurant
# 2     Japanese Restaurant
# 3             Bus Station
# 4             Bus Station
# 5             Bus Station
# 6             Bus Station
# 7       Korean Restaurant
# 8       Korean Restaurant
# 9       Korean Restaurant
# 10      Korean Restaurant
# 11           Liquor Store
# 12           Liquor Store
# 13                 Bakery
# 14                 Bakery
# 15           Dessert Shop
# 16                   Park
# 17                   Park
# 18                  Trail
# 19      Electronics Store

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(beecroft_merged['Latitude'], beecroft_merged['Longitude'], beecroft_merged['Neighborhood'], beecroft_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Examine Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
beecroft_merged.loc[beecroft_merged['Cluster Labels'] == 0, beecroft_merged.columns[[1] + list(range(5, beecroft_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 1     North Wahroonga                  Café                   Gym
# 2           Wahroonga                  Café                   Gym
# 3              Dundas           Pizza Place         Grocery Store
# 5            Oatlands           Pizza Place         Grocery Store
# 6             Telopea           Pizza Place         Grocery Store
# 7         Carlingford  Fast Food Restaurant                  Café
# 9   Carlingford North  Fast Food Restaurant                  Café
# 14          Westleigh                  Café           Pizza Place
# 15       North Epping       Thai Restaurant     Indian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1      Indian Restaurant      Asian Restaurant                  Park
# 2      Indian Restaurant      Asian Restaurant                  Park
# 3                   Café           Supermarket                   Pub
# 5                   Café           Supermarket                   Pub
# 6                   Café           Supermarket                   Pub
# 7          Train Station           Supermarket    Italian Restaurant
# 9          Train Station           Supermarket    Italian Restaurant
# 14       Thai Restaurant          Liquor Store    Chinese Restaurant
# 15           Pizza Place    Italian Restaurant           Social Club
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1     Chinese Restaurant                Bakery         Grocery Store
# 2     Chinese Restaurant                Bakery         Grocery Store
# 3   Fast Food Restaurant        Sandwich Place    Chinese Restaurant
# 5   Fast Food Restaurant        Sandwich Place    Chinese Restaurant
# 6   Fast Food Restaurant        Sandwich Place    Chinese Restaurant
# 7          Shopping Mall                   Gym  Gym / Fitness Center
# 9          Shopping Mall                   Gym  Gym / Fitness Center
# 14              Platform  Gym / Fitness Center  Fast Food Restaurant
# 15   Fried Chicken Joint      Football Stadium     Korean Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 1      Electronics Store    Japanese Restaurant
# 2      Electronics Store    Japanese Restaurant
# 3           Soccer Field            Bus Station
# 5           Soccer Field            Bus Station
# 6           Soccer Field            Bus Station
# 7             Food Court      Korean Restaurant
# 9             Food Court      Korean Restaurant
# 14         Shopping Mall                 Bakery
# 15      Malay Restaurant           Dessert Shop

# %% [markdown]
# #### Cluster 2

# %%
beecroft_merged.loc[beecroft_merged['Cluster Labels'] == 1, beecroft_merged.columns[[1] + list(range(5, beecroft_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0         Normanhurst                  Café                   Gym
# 4       Dundas Valley           Pizza Place         Grocery Store
# 8   Carlingford Court  Fast Food Restaurant                  Café
# 10          Kingsdene  Fast Food Restaurant                  Café
# 11           Beecroft                  Café           Pizza Place
# 12         Cheltenham                  Café           Pizza Place
# 13         Thornleigh                  Café           Pizza Place
# 16           Eastwood    Chinese Restaurant   Japanese Restaurant
# 17          Marsfield    Chinese Restaurant   Japanese Restaurant
# 19        Cherrybrook         Shopping Mall          Liquor Store
#
#    3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0      Indian Restaurant      Asian Restaurant                   Park
# 4                   Café           Supermarket                    Pub
# 8          Train Station           Supermarket     Italian Restaurant
# 10         Train Station           Supermarket     Italian Restaurant
# 11                Bakery       Thai Restaurant            Supermarket
# 12                Bakery       Thai Restaurant            Supermarket
# 13       Thai Restaurant          Liquor Store     Chinese Restaurant
# 16           Supermarket             BBQ Joint  Vietnamese Restaurant
# 17           Supermarket             BBQ Joint  Vietnamese Restaurant
# 19    Italian Restaurant         Grocery Store                   Park
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0     Chinese Restaurant                Bakery         Grocery Store
# 4   Fast Food Restaurant        Sandwich Place    Chinese Restaurant
# 8          Shopping Mall                   Gym  Gym / Fitness Center
# 10         Shopping Mall                   Gym  Gym / Fitness Center
# 11                   Zoo  Fast Food Restaurant                  Park
# 12                   Zoo  Fast Food Restaurant                  Park
# 13              Platform  Gym / Fitness Center  Fast Food Restaurant
# 16     Korean Restaurant                  Café       Thai Restaurant
# 17     Korean Restaurant                  Café       Thai Restaurant
# 19          Noodle House        Sandwich Place                  Café
#
#    9th Most Common Venue 10th Most Common Venue
# 0      Electronics Store    Japanese Restaurant
# 4           Soccer Field            Bus Station
# 8             Food Court      Korean Restaurant
# 10            Food Court      Korean Restaurant
# 11          Noodle House           Liquor Store
# 12          Noodle House           Liquor Store
# 13         Shopping Mall                 Bakery
# 16     Indian Restaurant                   Park
# 17     Indian Restaurant                   Park
# 19           Supermarket      Electronics Store

# %% [markdown]
# #### Cluster 3

# %%
beecroft_merged.loc[beecroft_merged['Cluster Labels'] == 2, beecroft_merged.columns[[1] + list(range(5, beecroft_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 18  West Pennant Hills           Pizza Place                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18                   Zoo                Bakery           Bus Station
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18                   Spa            Sports Bar          Liquor Store
#
#    9th Most Common Venue 10th Most Common Venue
# 18           Supermarket                  Trail
